# %%
import scipy.stats as stats #It has all the probability distributions available along with many statistical functions.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Employee_Salary_Dataset.csv')
data=df.copy()

# %%
data.head(5)
# Out:
#    ID  Experience_Years  Age  Gender  Salary
# 0   1                 5   28  Female  250000
# 1   2                 1   21    Male   50000
# 2   3                 3   23  Female  170000
# 3   4                 2   22    Male   25000
# 4   5                 1   17    Male   10000

# %%
data.tail(5)
# Out:
#     ID  Experience_Years  Age  Gender   Salary
# 30  31                10   34    Male    80000
# 31  32                15   54    Male   900000
# 32  33                20   55  Female  1540000
# 33  34                19   53  Female  9300000
# 34  35                16   49    Male  7600000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                35 non-null     int64
#  1   Experience_Years  35 non-null     int64
#  2   Age               35 non-null     int64
#  3   Gender            35 non-null     object
#  4   Salary            35 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.5+ KB

# %%
data.describe()
# Out:
#               ID  Experience_Years        Age        Salary
# count  35.000000          35.00000  35.000000  3.500000e+01
# mean   18.000000           9.20000  35.485714  2.059147e+06
# std    10.246951           7.55295  14.643552  3.170124e+06
# min     1.000000           1.00000  17.000000  3.000000e+03
# 25%     9.500000           2.50000  22.500000  2.250000e+04
# 50%    18.000000           6.00000  29.000000  2.500000e+05
# 75%    26.500000          15.00000  53.500000  3.270000e+06
# max    35.000000          27.00000  62.000000  1.000000e+07

# %%
data.shape
print ("Rows     : " , data.shape[0])
print ("Columns  : " , data.shape[1])
# Out:
# Rows     :  35
# Columns  :  5

# %%
data.isnull().sum().values.sum()
# Out:
# 0

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (35, 5)

# %%
print ("\nValues : \n", data.values)
print ("\nFeatures : \n", list(data.columns))
# Out:
# Values :
#  [[1 5 28 'Female' 250000]
#  [2 1 21 'Male' 50000]
#  [3 3 23 'Female' 170000]
#  [4 2 22 'Male' 25000]
#  [5 1 17 'Male' 10000]
#  [6 25 62 'Male' 5001000]
#  [7 19 54 'Female' 800000]
#  [8 2 21 'Female' 9000]
#  [9 10 36 'Female' 61500]
#  [10 15 54 'Female' 650000]
#  [11 4 26 'Female' 250000]
#  [12 6 29 'Male' 1400000]
#  [13 14 39 'Male' 6000050]
#  [14 11 40 'Male' 220100]
#  [15 2 23 'Male' 7500]
#  [16 4 27 'Female' 87000]
#  [17 10 34 'Female' 930000]
#  [18 15 54 'Female' 7900000]
#  [19 2 21 'Male' 15000]
#  [20 10 36 'Male' 330000]
#  [21 15 54 'Male' 6570000]
#  [22 4 26 'Male' 25000]
#  [23 5 29 'Male' 6845000]
#  [24 1 21 'Female' 6000]
#  [25 4 23 'Female' 8900]
#  [26 3 22 'Female' 20000]
#  [27 1 18 'Male' 3000]
#  [28 27 62 'Female' 10000000]
#  [29 19 54 'Female' 5000000]
#  [30 2 21 'Female' 6100]
#  [31 10 34 'Male' 80000]
#  [32 15 54 'Male' 900000]
#  [33 20 55 'Female' 1540000]
#  [34 19 53 'Female' 9300000]
#  [35 16 49 'Male' 7600000]]
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                35 non-null     int64
#  1   Experience_Years  35 non-null     int64
#  2   Age               35 non-null     int64
#  3   Gender            35 non-null     object
#  4   Salary            35 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.5+ KB

# %%
data.isnull().sum()
# Out:
# ID                  0
# Experience_Years    0
# Age                 0
# Gender              0
# Salary              0
# dtype: int64

# %%
data['Gender']=data['Gender'].astype("category")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                35 non-null     int64
#  1   Experience_Years  35 non-null     int64
#  2   Age               35 non-null     int64
#  3   Gender            35 non-null     category
#  4   Salary            35 non-null     int64
# dtypes: category(1), int64(4)
# memory usage: 1.4 KB

# %%
data.describe()
# Out:
#               ID  Experience_Years        Age        Salary
# count  35.000000          35.00000  35.000000  3.500000e+01
# mean   18.000000           9.20000  35.485714  2.059147e+06
# std    10.246951           7.55295  14.643552  3.170124e+06
# min     1.000000           1.00000  17.000000  3.000000e+03
# 25%     9.500000           2.50000  22.500000  2.250000e+04
# 50%    18.000000           6.00000  29.000000  2.500000e+05
# 75%    26.500000          15.00000  53.500000  3.270000e+06
# max    35.000000          27.00000  62.000000  1.000000e+07

# %%
list_col=  data.select_dtypes(['category']).columns
list_col
# Out:
# Index(['Gender'], dtype='object')

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Female    18
# Male      17
# Name: count, dtype: int64

# %%
def bar_perc(plot, feature):
    total = len(feature) 
    for p in plot.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total) 
        x = p.get_x() + p.get_width() / 2 - 0.05 
        y = p.get_y() + p.get_height()           
        plot.annotate(percentage, (x, y), size = 12)

# %%
no_of_male = len(data[data['Gender'] == 'Male'])
no_of_female = len(data[data['Gender'] == 'Female'])

plt.bar(['Male','Female'],[no_of_male,no_of_female],color = ['r','g'],label = ['Male','Female'])
plt.legend()
plt.show()

# %%
data
# Out:
#     ID  Experience_Years  Age  Gender    Salary
# 0    1                 5   28  Female    250000
# 1    2                 1   21    Male     50000
# 2    3                 3   23  Female    170000
# 3    4                 2   22    Male     25000
# 4    5                 1   17    Male     10000
# 5    6                25   62    Male   5001000
# 6    7                19   54  Female    800000
# 7    8                 2   21  Female      9000
# 8    9                10   36  Female     61500
# 9   10                15   54  Female    650000
# 10  11                 4   26  Female    250000
# 11  12                 6   29    Male   1400000
# 12  13                14   39    Male   6000050
# 13  14                11   40    Male    220100
# 14  15                 2   23    Male      7500
# 15  16                 4   27  Female     87000
# 16  17                10   34  Female    930000
# 17  18                15   54  Female   7900000
# 18  19                 2   21    Male     15000
# ...

# %%
corr_data = data[['ID','Age','Experience_Years','Salary']]

# %%
corr_data.corr()
# Out:
#                         ID       Age  Experience_Years    Salary
# ID                1.000000  0.282452          0.291098  0.362092
# Age               0.282452  1.000000          0.973708  0.668444
# Experience_Years  0.291098  0.973708          1.000000  0.685600
# Salary            0.362092  0.668444          0.685600  1.000000

# %%
plt.figure(figsize=(15,5))
sns.heatmap(corr_data.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.pairplot(data=data)
plt.show()

# %%
data.head()
# Out:
#    ID  Experience_Years  Age  Gender  Salary
# 0   1                 5   28  Female  250000
# 1   2                 1   21    Male   50000
# 2   3                 3   23  Female  170000
# 3   4                 2   22    Male   25000
# 4   5                 1   17    Male   10000

# %%
data.groupby(data.Gender).Salary.mean()
# Out:
# Gender
# Female    2.054917e+06
# Male      2.063626e+06
# Name: Salary, dtype: float64

# %%
sns.barplot(x=data.Gender,y=data.Salary).set(title='Gender Vs Salary')
# Out:
# [Text(0.5, 1.0, 'Gender Vs Salary')]

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x = data["Gender"], y =data["Experience_Years"],ci=1).set(title= 'Experience of males and females wrt Education')
plt.show()

# %%
data
# Out:
#     ID  Experience_Years  Age  Gender    Salary
# 0    1                 5   28  Female    250000
# 1    2                 1   21    Male     50000
# 2    3                 3   23  Female    170000
# 3    4                 2   22    Male     25000
# 4    5                 1   17    Male     10000
# 5    6                25   62    Male   5001000
# 6    7                19   54  Female    800000
# 7    8                 2   21  Female      9000
# 8    9                10   36  Female     61500
# 9   10                15   54  Female    650000
# 10  11                 4   26  Female    250000
# 11  12                 6   29    Male   1400000
# 12  13                14   39    Male   6000050
# 13  14                11   40    Male    220100
# 14  15                 2   23    Male      7500
# 15  16                 4   27  Female     87000
# 16  17                10   34  Female    930000
# 17  18                15   54  Female   7900000
# 18  19                 2   21    Male     15000
# ...

# %%
data.describe()
# Out:
#               ID  Experience_Years        Age        Salary
# count  35.000000          35.00000  35.000000  3.500000e+01
# mean   18.000000           9.20000  35.485714  2.059147e+06
# std    10.246951           7.55295  14.643552  3.170124e+06
# min     1.000000           1.00000  17.000000  3.000000e+03
# 25%     9.500000           2.50000  22.500000  2.250000e+04
# 50%    18.000000           6.00000  29.000000  2.500000e+05
# 75%    26.500000          15.00000  53.500000  3.270000e+06
# max    35.000000          27.00000  62.000000  1.000000e+07

# %%
category = pd.cut(data.Age,bins=[10,15,20,25,30,35,40,45,50,55,60],labels=['10-15','15-20','20-25','25-30','30-35','35-40','40-45','45-50','50-55','55-60'])
data.insert(1,'AgeGroup',category)

# %%
data
# Out:
#     ID AgeGroup  Experience_Years  Age  Gender    Salary
# 0    1    25-30                 5   28  Female    250000
# 1    2    20-25                 1   21    Male     50000
# 2    3    20-25                 3   23  Female    170000
# 3    4    20-25                 2   22    Male     25000
# 4    5    15-20                 1   17    Male     10000
# 5    6      NaN                25   62    Male   5001000
# 6    7    50-55                19   54  Female    800000
# 7    8    20-25                 2   21  Female      9000
# 8    9    35-40                10   36  Female     61500
# 9   10    50-55                15   54  Female    650000
# 10  11    25-30                 4   26  Female    250000
# 11  12    25-30                 6   29    Male   1400000
# 12  13    35-40                14   39    Male   6000050
# 13  14    35-40                11   40    Male    220100
# 14  15    20-25                 2   23    Male      7500
# ...

# %%
age_group = data.groupby(data.AgeGroup).Salary.mean()
age_group
# Out:
# AgeGroup
# 10-15             NaN
# 15-20    6.500000e+03
# 20-25    3.175000e+04
# 25-30    1.476167e+06
# 30-35    5.050000e+05
# 35-40    1.652912e+06
# 40-45             NaN
# 45-50    7.600000e+06
# 50-55    4.082500e+06
# 55-60             NaN
# Name: Salary, dtype: float64

# %%
category1=pd.cut(data['Experience_Years'],bins=[0,5,10,15,20],labels=['0-5','5-10','10-15','15-20'])
data.insert(6,'Exp_group',category1)

# %%
data.head()
# Out:
#    ID AgeGroup  Experience_Years  Age  Gender  Salary Exp_group
# 0   1    25-30                 5   28  Female  250000       0-5
# 1   2    20-25                 1   21    Male   50000       0-5
# 2   3    20-25                 3   23  Female  170000       0-5
# 3   4    20-25                 2   22    Male   25000       0-5
# 4   5    15-20                 1   17    Male   10000       0-5

# %%
age_group = data.groupby(data.Exp_group).Salary.mean()
age_group
# Out:
# Exp_group
# 0-5      4.580882e+05
# 5-10     5.603000e+05
# 10-15    3.706692e+06
# 15-20    4.848000e+06
# Name: Salary, dtype: float64

# %%
age_group.plot(kind='bar',title="Agebins vs Avg Salary")
# Out:
# <Axes: title={'center': 'Agebins vs Avg Salary'}, xlabel='Exp_group'>

# %%
Exp_bin_cat = data.groupby(data.Exp_group).Salary.mean()
Exp_bin_cat
# Out:
# Exp_group
# 0-5      4.580882e+05
# 5-10     5.603000e+05
# 10-15    3.706692e+06
# 15-20    4.848000e+06
# Name: Salary, dtype: float64

# %%
Exp_bin_cat.plot(kind='bar',title="Exp_bins vs Avg Salary")
# Out:
# <Axes: title={'center': 'Exp_bins vs Avg Salary'}, xlabel='Exp_group'>

# %%
data.groupby(['Gender','Exp_group']).Salary.mean()
# Out:
# Gender  Exp_group
# Female  0-5          8.966667e+04
#         5-10         4.957500e+05
#         10-15        4.275000e+06
#         15-20        4.160000e+06
# Male    0-5          8.725625e+05
#         5-10         6.033333e+05
#         10-15        3.422538e+06
#         15-20        7.600000e+06
# Name: Salary, dtype: float64

# %%
data.groupby(['Gender','Exp_group']).Salary.mean().unstack().plot(kind='bar',title="Exp_bins vs Avg Salary")
# Out:
# <Axes: title={'center': 'Exp_bins vs Avg Salary'}, xlabel='Gender'>

# %%
data.groupby(['Gender','Exp_group']).Salary.mean().unstack().plot(kind='bar',title="Exp_bins vs Avg Salary")
# Out:
# <Axes: title={'center': 'Exp_bins vs Avg Salary'}, xlabel='Gender'>

# %%
sns.relplot(x=data['Experience_Years'], y=data["Salary"], hue=data['Gender'],
            sizes=(40, 400), palette="spring",
            height=6, data=data).set(title='Salary by Gender,Experience');

# %%
data
# Out:
#     ID AgeGroup  Experience_Years  Age  Gender    Salary Exp_group
# 0    1    25-30                 5   28  Female    250000       0-5
# 1    2    20-25                 1   21    Male     50000       0-5
# 2    3    20-25                 3   23  Female    170000       0-5
# 3    4    20-25                 2   22    Male     25000       0-5
# 4    5    15-20                 1   17    Male     10000       0-5
# 5    6      NaN                25   62    Male   5001000       NaN
# 6    7    50-55                19   54  Female    800000     15-20
# 7    8    20-25                 2   21  Female      9000       0-5
# 8    9    35-40                10   36  Female     61500      5-10
# 9   10    50-55                15   54  Female    650000     10-15
# 10  11    25-30                 4   26  Female    250000       0-5
# 11  12    25-30                 6   29    Male   1400000      5-10
# 12  13    35-40                14   39    Male   6000050     10-15
# ...

# %%
sns.relplot(x=data['Salary'], y=data['Experience_Years'], hue=data['Gender'],
            sizes=(40, 400), palette="spring",
            height=6, data=data).set(title='Salary byGender,Experience');
