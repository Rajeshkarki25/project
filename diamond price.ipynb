# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pyplot import xticks
from matplotlib.pyplot import yticks

# %%
df = pd.DataFrame(pd.read_csv("diamonds.csv"))
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.shape
# Out:
# (53940, 11)

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
# Checking Null values
df.isnull().sum()
# There are no NULL values in the dataset, hence it is clean.
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df = df.dropna()

# %%
#EDA

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
auto = df

# %%
# Dimension reduction

# %%
cut = pd.get_dummies(df['cut'], drop_first = True)
cut
# Out:
#         Good  Ideal  Premium  Very Good
# 0      False   True    False      False
# 1      False  False     True      False
# 2       True  False    False      False
# 3      False  False     True      False
# 4       True  False    False      False
# ...      ...    ...      ...        ...
# 53935  False   True    False      False
# 53936   True  False    False      False
# 53937  False  False    False       True
# 53938  False  False     True      False
# 53939  False   True    False      False
#
# [53940 rows x 4 columns]

# %%
auto= pd.concat([auto,cut], axis = 1)
auto
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
# ...

# %%
color = pd.get_dummies(auto['color'], drop_first = False)
color
# Out:
#            D      E      F      G      H      I      J
# 0      False   True  False  False  False  False  False
# 1      False   True  False  False  False  False  False
# 2      False   True  False  False  False  False  False
# 3      False  False  False  False  False   True  False
# 4      False  False  False  False  False  False   True
# ...      ...    ...    ...    ...    ...    ...    ...
# 53935   True  False  False  False  False  False  False
# 53936   True  False  False  False  False  False  False
# 53937   True  False  False  False  False  False  False
# 53938  False  False  False  False   True  False  False
# 53939   True  False  False  False  False  False  False
#
# [53940 rows x 7 columns]

# %%
auto = pd.concat([auto,color], axis = 1)
auto
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
# ...

# %%
clarity = pd.get_dummies(auto['clarity'], drop_first = False)
clarity
# Out:
#           I1     IF    SI1    SI2    VS1    VS2   VVS1   VVS2
# 0      False  False  False   True  False  False  False  False
# 1      False  False   True  False  False  False  False  False
# 2      False  False  False  False   True  False  False  False
# 3      False  False  False  False  False   True  False  False
# 4      False  False  False   True  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...
# 53935  False  False   True  False  False  False  False  False
# 53936  False  False   True  False  False  False  False  False
# 53937  False  False   True  False  False  False  False  False
# 53938  False  False  False   True  False  False  False  False
# 53939  False  False  False   True  False  False  False  False
#
# [53940 rows x 8 columns]

# %%
auto = pd.concat([auto, clarity], axis = 1)
auto
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
# ...

# %%
auto
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
# ...

# %%
auto.drop(['cut','color','clarity'], axis = 1, inplace = True)

# %%
auto
# Out:
#        Unnamed: 0  carat  depth  table  price     x     y     z   Good  Ideal  \
# 0               1   0.23   61.5   55.0    326  3.95  3.98  2.43  False   True
# 1               2   0.21   59.8   61.0    326  3.89  3.84  2.31  False  False
# 2               3   0.23   56.9   65.0    327  4.05  4.07  2.31   True  False
# 3               4   0.29   62.4   58.0    334  4.20  4.23  2.63  False  False
# 4               5   0.31   63.3   58.0    335  4.34  4.35  2.75   True  False
# ...           ...    ...    ...    ...    ...   ...   ...   ...    ...    ...
# 53935       53936   0.72   60.8   57.0   2757  5.75  5.76  3.50  False   True
# 53936       53937   0.72   63.1   55.0   2757  5.69  5.75  3.61   True  False
# 53937       53938   0.70   62.8   60.0   2757  5.66  5.68  3.56  False  False
# 53938       53939   0.86   61.0   58.0   2757  6.15  6.12  3.74  False  False
# 53939       53940   0.75   62.2   55.0   2757  5.83  5.87  3.64  False   True
#
# ...

# %%
# Starting machine learning
import seaborn as sns
plt.figure(figsize=(35,10))
sns.heatmap(auto.corr(),annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# We specify this so that the train and test data set always have the same rows, respectively
df_train, df_test = train_test_split(auto, train_size = 0.7, test_size = 0.3, random_state = 1)

# %%
df_train = df_train.iloc[:,1:]

# %%
df_test = df_test.iloc[:,1:]

# %%
list(auto.keys())
# Out:
# ['Unnamed: 0',
#  'carat',
#  'depth',
#  'table',
#  'price',
#  'x',
#  'y',
#  'z',
#  'Good',
#  'Ideal',
#  'Premium',
#  'Very Good',
#  'D',
#  'E',
#  'F',
#  'G',
#  'H',
#  'I',
#  'J',
#  'I1',
#  'IF',
#  'SI1',
#  'SI2',
#  'VS1',
#  'VS2',
#  'VVS1',
#  'VVS2']

# %%
from sklearn.linear_model import LinearRegression
X_train = df_train[['carat',
 'depth',
 'table',
 'x',
 'y',
 'z',
 'Good',
 'Ideal',
 'Premium',
 'Very Good',
 'D',
 'E',
 'F',
 'G',
 'H',
 'I',
 'J',
 'I1',
 'IF',
 'SI1',
 'SI2',
 'VS1',
 'VS2',
 'VVS1',
 'VVS2']]
y_train = df_train[['price']]
# # df_test_predict = X_train.iloc[0:1]

# %%
X_train
# Out:
#        carat  depth  table     x     y     z   Good  Ideal  Premium  \
# 30083   0.32   61.5   56.0  4.42  4.40  2.71  False   True    False
# 21864   1.54   62.8   58.0  7.35  7.32  4.61  False  False     True
# 3761    0.71   62.1   56.0  5.69  5.75  3.55  False   True    False
# 21262   1.03   62.0   56.0  6.48  6.45  4.01  False   True    False
# 15460   1.33   62.4   55.0  7.02  7.05  4.39  False   True    False
# ...      ...    ...    ...   ...   ...   ...    ...    ...      ...
# 50057   0.70   62.8   59.0  5.56  5.61  3.51  False  False    False
# 32511   0.40   63.9   57.0  4.71  4.65  2.99   True  False    False
# 5192    0.91   62.7   63.0  6.05  6.00  3.78  False  False    False
# 12172   1.18   61.7   56.0  6.79  6.82  4.20  False   True    False
# 33003   0.32   60.9   56.0  4.41  4.43  2.69  False   True    False
#
#        Very Good  ...      I      J     I1     IF    SI1    SI2    VS1    VS2  \
# ...

# %%
y_train
# Out:
#        price
# 30083    720
# 21864   9926
# 3761    3457
# 21262   9413
# 15460   6190
# ...      ...
# 50057   2202
# 32511    798
# 5192    3776
# 12172   5182
# 33003    813
#
# [37758 rows x 1 columns]

# %%
lm = LinearRegression()
model = lm.fit(X_train, y_train)

# %%
# Testing
data = df_test.iloc[0:1]
actual_price = data.pop('price')

print(data)
predicted_price = model.predict(data)
print("Actual price",actual_price)
print("predicted expenses",predicted_price)
print(df_test.iloc[0:1])
# Out:
#       carat  depth  table     x     y     z   Good  Ideal  Premium  Very Good  \
# 2714   0.33   61.7   55.0  4.43  4.46  2.74  False   True    False      False
#
#       ...      I      J     I1     IF   SI1    SI2    VS1    VS2   VVS1   VVS2
# 2714  ...  False  False  False  False  True  False  False  False  False  False
#
# [1 rows x 25 columns]
# Actual price 2714    564
# Name: price, dtype: int64
# predicted expenses [[-570.1745487]]
#       carat  depth  table  price     x     y     z   Good  Ideal  Premium  \
# 2714   0.33   61.7   55.0    564  4.43  4.46  2.74  False   True    False
#
#       ...      I      J     I1     IF   SI1    SI2    VS1    VS2   VVS1   VVS2
# 2714  ...  False  False  False  False  True  False  False  False  False  False
#
# [1 rows x 26 columns]
